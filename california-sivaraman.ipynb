# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/california-housing-dataset-kongu/sample_submission.csv
# /kaggle/input/california-housing-dataset-kongu/train.csv
# /kaggle/input/california-housing-dataset-kongu/test.csv

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor

# %%
train_df=pd.read_csv("/kaggle/input/california-housing-dataset-kongu/train.csv")
test_df=pd.read_csv("/kaggle/input/california-housing-dataset-kongu/test.csv")
train_df.isnull().sum()
# Out:
# id             0
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
test_df
# Out:
#           id  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0      37137  1.7062      35.0  4.966368   1.096539      1318.0  2.844411
# 1      37138  1.3882      22.0  4.187035   1.098229      2296.0  3.180218
# 2      37139  7.7197      21.0  7.129436   0.959276      1535.0  2.888889
# 3      37140  4.6806      49.0  4.769697   1.048485       707.0  1.743590
# 4      37141  3.1284      25.0  3.765306   1.081633      4716.0  2.003827
# ...      ...     ...       ...       ...        ...         ...       ...
# 24754  61891  2.2875      34.0  3.914729   1.085271       866.0  2.071429
# 24755  61892  3.0781      33.0  4.771971   1.038674      1628.0  2.326848
# 24756  61893  2.6961      14.0  4.593960   1.170380      3900.0  2.540034
# 24757  61894  7.2315       8.0  7.508403   1.018692      1388.0  2.601202
# 24758  61895  5.7260      30.0  6.000000   1.000000        15.0  2.500000
#
#        Latitude  Longitude
# 0         39.75    -121.85
# ...

# %%
y=train_df['MedHouseVal'];
train_df.drop('MedHouseVal',axis=1,inplace=True);
train_df.drop('id',axis=1,inplace=True);
u=test_df['id']

# %%
xtr,xte,ytr,yte=train_test_split(train_df,y,test_size=0.2);
model = CatBoostRegressor(iterations= 1000,
    learning_rate= 0.05,
    depth= 4,
    l2_leaf_reg= 3,
    bagging_temperature= 0.8)
model.fit(train_df,y)
ype=model.predict(test_df)
final=pd.DataFrame(data=(u),columns=['id']);
final.loc[:,"MedHouseVal"]=ype
# Out:
# 0:	learn: 1.1290623	total: 59ms	remaining: 59s
# 1:	learn: 1.1021344	total: 62.9ms	remaining: 31.4s
# 2:	learn: 1.0766490	total: 66.3ms	remaining: 22s
# 3:	learn: 1.0531942	total: 70.2ms	remaining: 17.5s
# 4:	learn: 1.0313923	total: 74.2ms	remaining: 14.8s
# 5:	learn: 1.0106973	total: 78.1ms	remaining: 12.9s
# 6:	learn: 0.9912932	total: 81.5ms	remaining: 11.6s
# 7:	learn: 0.9728404	total: 84.8ms	remaining: 10.5s
# 8:	learn: 0.9561676	total: 88.1ms	remaining: 9.7s
# 9:	learn: 0.9405249	total: 92.1ms	remaining: 9.12s
# 10:	learn: 0.9256909	total: 96ms	remaining: 8.63s
# 11:	learn: 0.9114588	total: 100ms	remaining: 8.23s
# 12:	learn: 0.8980852	total: 104ms	remaining: 7.9s
# 13:	learn: 0.8861116	total: 108ms	remaining: 7.61s
# 14:	learn: 0.8750119	total: 112ms	remaining: 7.32s
# 15:	learn: 0.8638776	total: 115ms	remaining: 7.06s
# 16:	learn: 0.8534293	total: 118ms	remaining: 6.83s
# 17:	learn: 0.8434999	total: 121ms	remaining: 6.63s
# 18:	learn: 0.8337768	total: 125ms	remaining: 6.44s
# ...

# %%
final.to_csv("submission",index=False)
sub=pd.read_csv("./submission")
sub
# Out:
#           id  MedHouseVal
# 0      37137     0.624687
# 1      37138     1.069424
# 2      37139     4.265710
# 3      37140     3.493089
# 4      37141     2.550286
# ...      ...          ...
# 24754  61891     2.385958
# 24755  61892     1.847419
# 24756  61893     1.189786
# 24757  61894     3.859185
# 24758  61895     3.697839
#
# [24759 rows x 2 columns]
